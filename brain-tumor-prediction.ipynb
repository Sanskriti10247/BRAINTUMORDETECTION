# %%
from ultralytics import YOLO

# %%
trained_model = YOLO(r'/Users/Sanskriti/Desktop/brain-tumor-2/runs/detect/train/weights/best.pt')
results = trained_model(r'/Users/Sanskriti/Desktop/brain-tumor-2/images1.jpg')

# %%
import matplotlib.pyplot as plt
from PIL import Image
# Ensure matplotlib inline mode
# %matplotlib inline
# Assuming results[0].plot() returns an array
image_array = results[0].plot()

# Display the image
plt.imshow(image_array)
plt.axis('off')  # Hide axes
plt.show()
